# %%
import numpy as np

# List comprehension
# %timeit [x**0.5 for x in range(100000)]

# Numpy
# %timeit np.sqrt(np.arange(100000))
# Out:
# 5.34 ms ± 49.2 μs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 110 μs ± 806 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)
