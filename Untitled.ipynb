# %%
# Cell 1 — benchmark with timeit
import numpy as np
# %timeit np.random.randn(10000)
# Out:
# 282 μs ± 91.9 μs per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
# Cell 2 — time a full cell
# %time
result = [x**2 for x in range(1000000)]
# Out:
# CPU times: user 3 μs, sys: 1 μs, total: 4 μs
# Wall time: 6.91 μs

# %%
# Cell 3 — inline plots
# %matplotlib inline
import matplotlib.pyplot as plt
plt.plot([1, 2, 3, 4], [1, 4, 2, 3])
plt.title("My first inline plot")
plt.show()
# Out:
# Matplotlib is building the font cache; this may take a moment.
